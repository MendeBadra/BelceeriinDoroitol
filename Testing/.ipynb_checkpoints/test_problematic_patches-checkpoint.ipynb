# %%
import rasterio
import rasterio.plot
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
# %pwd
# Out:
# '/media/razydave/01DA189A333B1070/MendeFolder/08_BelceeriinDoroitol/Testing'

# %%
raster_path_drone = '../Drone_Orthomosaics/Orthos2024_10/5_Worst_2024_10_02/P4_MS/Worst_2024_10_P4_MS.tif'
src_drone = rasterio.open(raster_path_drone)
print(src_drone)
# Out:
# <open DatasetReader name='../Drone_Orthomosaics/Orthos2024_10/5_Worst_2024_10_02/P4_MS/Worst_2024_10_P4_MS.tif' mode='r'>

# %%
raster_path = "https://github.com/opengeos/datasets/releases/download/raster/dem_90m.tif"
src = rasterio.open(raster_path)
print(src)
# Out:
# <open DatasetReader name='https://github.com/opengeos/datasets/releases/download/raster/dem_90m.tif' mode='r'>

# %%
src.name
# Out:
# 'https://github.com/opengeos/datasets/releases/download/raster/dem_90m.tif'

# %%
src.mode
# Out:
# 'r'

# %%
src.meta
# Out:
# {'driver': 'GTiff',
#  'dtype': 'int16',
#  'nodata': None,
#  'width': 4269,
#  'height': 3113,
#  'count': 1,
#  'crs': CRS.from_epsg(3857),
#  'transform': Affine(90.0, 0.0, -13442488.3428,
#         0.0, -89.99579177642138, 4668371.5775)}

# %%
src_drone.meta
# Out:
# {'driver': 'GTiff',
#  'dtype': 'float32',
#  'nodata': None,
#  'width': 8899,
#  'height': 9423,
#  'count': 6,
#  'crs': CRS.from_epsg(32648),
#  'transform': Affine(0.02499767303932929, 0.0, 563466.7548045829,
#         0.0, -0.02499997591767644, 5266764.67591036)}

# %%
src_drone.res
# Out:
# (0.02499767303932929, 0.02499997591767644)

# %% [markdown]
# `src.width` == how many columns
# `src.height` == how many rows

# %%
src.width, src.height
# Out:
# (4269, 3113)

# %% [markdown]
# Number looks huge because of epsg 3857

# %%
src_drone.width
# Out:
# 8899

# %%
src_drone.transform
# Out:
# Affine(0.02499767303932929, 0.0, 563466.7548045829,
#        0.0, -0.02499997591767644, 5266764.67591036)

# %%
rasterio.plot.show(src_drone,1)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# <Axes: >

# %%
src_drone.dtypes
# Out:
# ('float32', 'float32', 'float32', 'float32', 'float32', 'float32')

# %% [markdown]
# Example vector

# %%
fig, ax = plt.subplots(figsize=(8, 8))
rasterio.plot.show(src, cmap="terrain", ax=ax, title="Digital Elevation Model (DEM)")
plt.show()

# %%
dem_bounds = (
    "https://github.com/opengeos/datasets/releases/download/places/dem_bounds.geojson"
)
gdf = gpd.read_file(dem_bounds)
gdf = gdf.to_crs(src.crs)

# %%
fig, ax = plt.subplots(figsize=(8, 8))
rasterio.plot.show(src, cmap="terrain", ax=ax, title="Digital Elevation Model (DEM)")
gdf.plot(ax=ax, edgecolor="red", facecolor="none", lw=2)
# Out:
# <Axes: title={'center': 'Digital Elevation Model (DEM)'}>

# %% [markdown]
# ### Basic Band Math

# %%
nir_band = src_drone.read(4)
red_band = src_drone.read(1)

# %%
ndvi = (nir_band - red_band) / (nir_band + red_band)
ndvi.clip(0, 1)

plt.figure(figsize=(10, 10))
plt.imshow(ndvi, cmap="summer")
# Out:
# /tmp/ipykernel_87054/3642608147.py:1: RuntimeWarning: invalid value encountered in divide
#   ndvi = (nir_band - red_band) / (nir_band + red_band)

# %% [markdown]
# ### Objective: Find slices of misbehaving patches and investigate them separatly
